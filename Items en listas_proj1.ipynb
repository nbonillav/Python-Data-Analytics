# %% [markdown]
# ## Proyecto Final
#
# Crear un menu dinámico, que pregunte hasta indicar lo contrario si quiere agregar un item a las lista:
# Lista de series
# Lista de Canciones
# Lista de Juegos

# %%
def menu():
    print("-------------------------")
    print("Hola!")
    name = input("Cual es su nombre? ")
    print("-------------------------")

    def open_append_close(categ):
        category = "my-" + str(categ) + ".txt"
        # print(category)
        file = open(category, "a")
        if categ == 'songs':
            insert_stuff = input("Agregue una Canción: ")
        elif categ == 'series':
            insert_stuff = input("Agregue una Serie: ")
        else:
            insert_stuff = input("Agregue un Juego: ")
        print('---------------------------------\n')
        file.write(insert_stuff + "\n")
        file.close()
        return insert_stuff

    def read_files():
        categories = ['songs', 'series', 'games']
        for i in categories:
            category = "my-" + str(i) + ".txt"
            file = open(category, "r+")
            print('---------------------------------')
            print(category)
            print('---------------------------------')
            print(file.read())


    while(True):
        print("Bienvenid@", name)
        print("1. Agregar a lista de Canciones")
        print("2. Agregar a lista de Series")
        print("3. Agregar a lista de Juegos")
        print("4. Salir")
        answer = input("Elija una opcion: ")

        if answer == "1":
            open_append_close('songs')
        elif answer == "2":
            open_append_close('series')
        elif answer == "3":
            open_append_close('games')
        elif answer == "4":
            break
        else:
            read_files()

menu()
# Out:
# -------------------------
# Hola!
# -------------------------
# Bienvenid@
# 1. Agregar a lista de Canciones
# 2. Agregar a lista de Series
# 3. Agregar a lista de Juegos
# 4. Salir
# ---------------------------------
# my-songs.txt
# ---------------------------------
# the line
# enemy
# my hero
# Unwritten
# Misfit toys - Pusha T, Mako
# Come Play - Stray Kids, Young Miko, Tom Morello
# Playground - Bea Miller
# Whatever it takes - Imagine Dragons
#
# ---------------------------------
# my-series.txt
# ---------------------------------
# arcane
# grey's anatomy
# Bones
# Naruto
# The last of us
# Legends' of Tomorrow
# The walking dead
# Caballeros del Zodiaco
# The Good Doctor
#
# ---------------------------------
# my-games.txt
# ---------------------------------
# GTA 5
# Legends of Runterra
# Call of Duty
# Mario Bros
# Project zomboid
# Pokemon Unite
#
# Bienvenid@
# 1. Agregar a lista de Canciones
# 2. Agregar a lista de Series
# 3. Agregar a lista de Juegos
# 4. Salir
# ...
