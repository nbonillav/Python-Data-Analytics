# %% [markdown]
# ## Tarea 2

# %% [markdown]
# 1. Abra el dataset "Euro_2012_stats_TEAM.csv". Es un dataset que contiene estadísticas de la Eurocopa 2012.
# 2. Use algunos de las funciones vistas en clase para conocer mejor los datos.
# 3. Haga un nuevo dataset llamado "discipline" que contenga las variables "Team", "Yellow Cards" y "Red Cards".
# 4. ¿Cuál fue el equipo con mayor número de tarjetas amarillas recibidas? Muestre el código que usó para obtener el resultado.
# 5. Volviendo al dataset original (no al nuevo dataset "discipline"), ¿Cuáles fueron los equipos que hicieron más de 6 goles? Muestre el código que usó para obtener el resultado.
# 6. Cuál fue el equipo con la menor cantidad de faltas concedidas (Fouls Conceded)? Muestre el código que usó para obtener el resultado.
# 7. ¿Hay alguna relación evidente entre las variables "Shots on target" y "Shots off target"? Genere un gráfico para determinarlo.

# %%
import pandas as pd

# %%
#Abra el dataset "Euro_2012_stats_TEAM.csv". Es un dataset que contiene estadísticas de la Eurocopa 2012.
euro = pd.read_csv("Euro_2012_stats_TEAM.csv")
euro.head(5)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
# 2.Use algunos de las funciones vistas en clase para conocer mejor los datos.
euro.describe()
# Out:
#            Goals  Shots on target  Shots off target  \
# count  16.000000        16.000000         16.000000
# mean    4.750000        17.125000         24.937500
# std     2.886751        10.582218         10.680005
# min     1.000000         7.000000         10.000000
# 25%     2.750000         9.750000         18.000000
# 50%     4.500000        13.000000         23.500000
# 75%     5.250000        22.000000         32.250000
# max    12.000000        42.000000         45.000000
#
#        Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# count                   16.000000     16.000000      16.000000
# mean                    54.937500      1.250000       0.187500
# std                     26.065223      1.612452       0.403113
# min                     27.000000      0.000000       0.000000
# 25%                     36.500000      0.000000       0.000000
# 50%                     44.000000      1.000000       0.000000
# ...

# %%
euro[["Team", "Goals"]].agg(['max', 'min'])
# Out:
#         Team  Goals
# max  Ukraine     12
# min  Croatia      1

# %%
euro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
euro[["Passes completed", "Passes"]].agg(['mean', 'median'])
# Out:
#         Passes completed    Passes
# mean            1467.375  1763.375
# median          1211.500  1522.000

# %%
euro["Team"].value_counts()
# Out:
# Team
# Croatia                1
# Czech Republic         1
# Denmark                1
# England                1
# France                 1
# Germany                1
# Greece                 1
# Italy                  1
# Netherlands            1
# Poland                 1
# Portugal               1
# Republic of Ireland    1
# Russia                 1
# Spain                  1
# Sweden                 1
# Ukraine                1
# Name: count, dtype: int64

# %%
euro.groupby("Team")["Goals"].mean()
# Out:
# Team
# Croatia                 4.0
# Czech Republic          4.0
# Denmark                 4.0
# England                 5.0
# France                  3.0
# Germany                10.0
# Greece                  5.0
# Italy                   6.0
# Netherlands             2.0
# Poland                  2.0
# Portugal                6.0
# Republic of Ireland     1.0
# Russia                  5.0
# Spain                  12.0
# Sweden                  5.0
# Ukraine                 2.0
# Name: Goals, dtype: float64

# %%
# 3. Haga un nuevo dataset llamado "discipline" que contenga las variables "Team", "Yellow Cards" y "Red Cards".
discipline = pd.read_csv('Euro_2012_stats_TEAM.csv')

# %%
discipline.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
discipline = discipline.drop(['Goals', 'Shots on target', 'Shots off target',
       'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
       'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
       'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
       'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
       'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
       'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
       'Offsides', 'Subs on', 'Subs off',
       'Players Used'], axis = 1)

# %%
discipline.columns
# Out:
# Index(['Team', 'Yellow Cards', 'Red Cards'], dtype='object')

# %%
# 4. ¿Cuál fue el equipo con mayor número de tarjetas amarillas recibidas? Muestre el código que usó para obtener el resultado.
discipline.max()
# Out:
# Team            Ukraine
# Yellow Cards         16
# Red Cards             1
# dtype: object

# %%
# 5. Volviendo al dataset original (no al nuevo dataset "discipline")
#¿Cuáles fueron los equipos que hicieron más de 6 goles? Muestre el código que usó para obtener el resultado.

# %%
euro[euro["Goals"] > 6].head()
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# 6.Cuál fue el equipo con la menor cantidad de faltas concedidas (Fouls Conceded)? Muestre el código que usó para obtener el resultado.

# %%
euro[["Team", "Fouls Conceded"]].agg(['min'])
# Out:
#         Team  Fouls Conceded
# min  Croatia              30

# %%
# 7.¿Hay alguna relación evidente entre las variables "Shots on target" y "Shots off target"? Genere un gráfico para determinarlo.

# %%
import seaborn as sns
import matplotlib.pyplot as plt #Librería de visualización
import seaborn as sns #Otra librería de visualización

# %%
sns.scatterplot(x='Shots on target', y='Shots off target', data=euro)
# Out:
# <Axes: xlabel='Shots on target', ylabel='Shots off target'>

# %%
# No se observa ningún patrón entre ambas variables
